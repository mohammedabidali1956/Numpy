# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedabidali1956/Numpy/blob/main/Intro_Pandas_%26_Data_Manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introduction to Pandas Data Structures
# • What is Pandas?
# • Pandas Data Structures
# • Series
# • DataFrame

# %%
import pandas as pd

# %%
# Series Data Structures in pandas

data = pd.Series([100,200,300])
s = pd.Series([10,20,30],index = ["a","b","c"])

print(data)
print(s)
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# Pandas DataFrame
#
# A DataFrame is a two-dimensional, size-mutable and potentially heterogeneous tabular data structure with labeled axes (rows and columns).

# %%
data = {"Name":['Alice','Bob'], "Age": [20,30]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0  Alice   20
# 1    Bob   30

# %% [markdown]
# Loading data from csv,excel and others sources

# %%
# From csv file
#df = pd.read_csv("data.csv")
# from excel file
df1 = pd.read_excel("drl prices list.xlsx")
print(df1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1855577136.py in <cell line: 0>()
#       2 #df = pd.read_csv("data.csv")
#       3 # from excel file
# ----> 4 df1 = pd.read_excel("drl prices list.xlsx")
#       5 print(df1)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %% [markdown]
# Saving data
# - Save to CSV
# - Save to Excel

# %%
df1 = pd.read_excel("drl prices list.xlsx")
df1.to_xlsx("drl prices list.xlsx")
df.to_csv("data.csv")

# %%
data = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-total-female-births.csv')
#print(data.head()) #Gives first 5 rows of the dataset
print(data.head(6))
# Out:
#          Date  Births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44
# 5  1959-01-06      29

# %%
print(data.tail(6))
# Out:
#            Date  Births
# 359  1959-12-26      34
# 360  1959-12-27      37
# 361  1959-12-28      52
# 362  1959-12-29      48
# 363  1959-12-30      55
# 364  1959-12-31      50

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    365 non-null    object
#  1   Births  365 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.8+ KB
# None

# %%
print(data.describe())
# Out:
#            Births
# count  365.000000
# mean    41.980822
# std      7.348257
# min     23.000000
# 25%     37.000000
# 50%     42.000000
# 75%     46.000000
# max     73.000000

# %%
print(data["Date"])
print(data[["Date","Births"]])
# Out:
# 0      1959-01-01
# 1      1959-01-02
# 2      1959-01-03
# 3      1959-01-04
# 4      1959-01-05
#           ...
# 360    1959-12-27
# 361    1959-12-28
# 362    1959-12-29
# 363    1959-12-30
# 364    1959-12-31
# Name: Date, Length: 365, dtype: object
#            Date  Births
# 0    1959-01-01      35
# 1    1959-01-02      32
# 2    1959-01-03      30
# 3    1959-01-04      31
# 4    1959-01-05      44
# ..          ...     ...
# 360  1959-12-27      37
# 361  1959-12-28      52
# 362  1959-12-29      48
# 363  1959-12-30      55
# 364  1959-12-31      50
#
# [365 rows x 2 columns]

# %% [markdown]
# *selecting rows by position*

# %% [markdown]
# iloc
# is a Pandas function that selects data based on its numerical position (integer index) rather than labels.
# - Syntax:  df.iloc[row_index, column_index]

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv')

#print(df.iloc[1:4])
print(df.iloc[0:3,0:3])
# Out:
#    longitude  latitude  housing_median_age
# 0    -114.31     34.19                15.0
# 1    -114.47     34.40                19.0
# 2    -114.56     33.69                17.0

# %% [markdown]
# *Selecting by label*

# %%
print(df.loc[:5,"longitude"])
# Out:
# 0   -114.31
# 1   -114.47
# 2   -114.56
# 3   -114.57
# 4   -114.57
# 5   -114.58
# Name: longitude, dtype: float64

# %% [markdown]
# ##Hands On Exercise

# %%
#Ex1: load and explore sample dataset
import pandas as pd

#load
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv")

#Explore

# print("First 5 rows:\n",df.head(5))
# print("\nLast 5 rows:\n",df.tail(5))

# print(df.info())
# print("\n",df.describe())
print(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Ex 2: Select specific columns and rows

selected_columns = df[["sepal_length","species"]]
#print("selected columns: \n",selected_columns)

filtered_rows = df[(df["petal_length"]>5.0)&(df['species']=="virginica")]
# print("Filtered data: \n",filtered_rows)
# Out:
# Filtered data:
#       sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...
